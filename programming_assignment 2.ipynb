# %%
###Shariff Mohammed (40054557)

import pandas as pd
import numpy as np

#1st data example
data = pd.read_csv('tips.csv')

##PART 1 QUANTITATIVE DESCRIPTIONS
def quantDDA(data):
    unique_entries = data.nunique() 
    missing_entries = data.isnull().sum()
    mode = data.mode()[0:1] 
    mean = data.mean()
    std = data.std()
    minim = data.min()
    maxim = data.max()
    q3 = data.quantile(0.75)
    q2_median = data.quantile(0.5)
    q1 = data.quantile(0.25)
    IQR = q3 - q1
    extreme_vals_lower = q3 - (3 * IQR)
    extreme_vals_upper = q3 + (3 * IQR)
    outliers = ((data < (q1 - 1.5 * IQR)) | (data > (q3 + 1.5 * IQR))).sum()
    skew = data.skew()
    kurtosis = data.kurt()
    
    
    #Part 3
    data["MissingValueCount"] = data.apply(lambda x: x.isnull().sum(), axis=1) #creating new column for dataset
    display(data)
    
    print('Number of observations:', len(data))
    print('Number of entries:', data.size,'\n\n')
    print('Displaying mode:')
    display(mode)
    
    result = pd.concat([
                      unique_entries.rename('unique_entries'),  
                      missing_entries.rename('missing_entries'),
                      extreme_vals_lower.rename('extr_val_lower'),
                      extreme_vals_upper.rename('extr_val_upper'),
                      outliers.rename('outliers'),
                      mean.rename('mean'),
                      std.rename('std_dev'),
                      maxim.rename('max'),
                      minim.rename('min'),
                      q3.rename('Q3'),
                      q2_median.rename('Q2 (med)'),
                      q1.rename('Q1'),
                      skew.rename('skew'),
                      kurtosis.rename('kurtosis')], axis=1).T #wasn't sure if we keep the 1st column unamed so I left it there incase
    print('\n\n Displaying rest of the quantitative desciptions:')
    display(result)

    
quantDDA(data)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size  \
# 0             1       16.99  1.01  Female     No   Sun  Dinner     2
# 1             2       10.34  1.66    Male     No   Sun  Dinner     3
# 2             3       21.01  3.50    Male     No   Sun  Dinner     3
# 3             4       23.68  3.31    Male     No   Sun  Dinner     2
# 4             5       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         240       29.03  5.92    Male     No   Sat  Dinner     3
# 240         241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         243       17.82  1.75    Male     No   Sat  Dinner     2
# 243         244       18.78  3.00  Female     No  Thur  Dinner     2
#
#      MissingValueCount
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 239                  0
# 240                  0
# 241                  0
# 242                  0
# 243                  0
#
# [244 rows x 9 columns]
# Number of observations: 244
# Number of entries: 2196
#
#
# Displaying mode:
#    Unnamed: 0  total_bill  tip   sex smoker  day    time  size
# 0           1       13.42  2.0  Male     No  Sat  Dinner   2.0
#  Displaying rest of the quantitative desciptions:
#                 Unnamed: 0 total_bill      tip     sex smoker   day    time  \
# unique_entries         244        229      123       2      2     4       2
# missing_entries          0          0        0       0      0     0       0
# extr_val_lower     -181.25    -8.2125   -1.125     NaN    NaN   NaN     NaN
# extr_val_upper      547.75    56.4675     8.25     NaN    NaN   NaN     NaN
# outliers                 0          9        9       0      0     0       0
# mean                 122.5    19.7859  2.99828     NaN    NaN   NaN     NaN
# std_dev            70.5809    8.90241  1.38364     NaN    NaN   NaN     NaN
# max                    244      50.81       10    Male    Yes  Thur   Lunch
# min                      1       3.07        1  Female     No   Fri  Dinner
# Q3                  183.25    24.1275   3.5625     NaN    NaN   NaN     NaN
# Q2 (med)             122.5     17.795      2.9     NaN    NaN   NaN     NaN
# Q1                   61.75    13.3475        2     NaN    NaN   NaN     NaN
# skew                     0    1.13321  1.46545     NaN    NaN   NaN     NaN
# kurtosis              -1.2    1.21848  3.64838     NaN    NaN   NaN     NaN
#
#                     size
# unique_entries         6
# missing_entries        0
# extr_val_lower         0
# extr_val_upper         6
# outliers               9
# mean             2.56967
# std_dev           0.9511
# max                    6
# min                    1
# Q3                     3
# Q2 (med)               2
# Q1                     2
# skew             1.44788
# kurtosis          1.7317

# %%
import seaborn as sns
import matplotlib.pyplot as plt

##PART 2 
def vizDDA(data):
    sns.pairplot(data)

vizDDA(data)

# %%
#Testing functions on a different data set 2nd example
data2 = pd.read_csv('surveys.csv')
quantDDA(data2)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight  MissingValueCount
# 0         NaN                  1
# 1         NaN                  1
# 2         NaN                  1
# 3         NaN                  1
# 4         NaN                  1
# ...       ...                ...
# 35544     NaN                  3
# 35545     NaN                  3
# 35546    14.0                  0
# 35547    51.0                  0
# 35548     NaN                  4
#
# [35549 rows x 10 columns]
# Number of observations: 35549
# Number of entries: 355490
#
#
# Displaying mode:
#    record_id  month   day    year  plot_id species_id sex  hindfoot_length  \
# 0          1    7.0  16.0  1997.0     12.0         DM   M             36.0
#
#    weight
# 0    46.0
#  Displaying rest of the quantitative desciptions:
#                     record_id      month        day         year    plot_id  \
# unique_entries   35549.000000  12.000000  31.000000    26.000000  24.000000
# missing_entries      0.000000   0.000000   0.000000     0.000000   0.000000
# extr_val_lower  -26660.000000  -8.000000 -19.000000  1958.000000 -19.000000
# extr_val_upper   79984.000000  28.000000  65.000000  2036.000000  53.000000
# outliers             0.000000   0.000000   0.000000     0.000000   0.000000
# mean             17775.000000   6.477847  15.991195  1990.475231  11.397001
# std_dev          10262.256696   3.396925   8.257366     7.493355   6.799406
# max              35549.000000  12.000000  31.000000  2002.000000  24.000000
# min                  1.000000   1.000000   1.000000  1977.000000   1.000000
# Q3               26662.000000  10.000000  23.000000  1997.000000  17.000000
# Q2 (med)         17775.000000   6.000000  16.000000  1990.000000  11.000000
# Q1                8888.000000   4.000000   9.000000  1984.000000   5.000000
# skew                 0.000000   0.049958   0.013881    -0.044146   0.121433
# kurtosis            -1.200000  -1.204902  -1.062835    -1.284773  -1.147823
#
#                  species_id     sex  hindfoot_length       weight
# unique_entries         48.0     2.0        56.000000   255.000000
# missing_entries       763.0  2511.0      4111.000000  3266.000000
# extr_val_lower          NaN     NaN        -9.000000   -36.000000
# extr_val_upper          NaN     NaN        81.000000   132.000000
# outliers                0.0     0.0         2.000000  3178.000000
# mean                    NaN     NaN        29.287932    42.672428
# std_dev                 NaN     NaN         9.564759    36.631259
# max                     NaN     NaN        70.000000   280.000000
# min                     NaN     NaN         2.000000     4.000000
# Q3                      NaN     NaN        36.000000    48.000000
# Q2 (med)                NaN     NaN        32.000000    37.000000
# Q1                      NaN     NaN        21.000000    20.000000
# skew                    NaN     NaN         0.317434     2.331087
# kurtosis                NaN     NaN        -0.606196     6.138654

# %%
vizDDA(data2)

# %%
#Testing functions on one last different data set 3rd and last example
data3 = pd.read_csv('SN7577i_d.csv')
quantDDA(data3)
# Out:
#    Id  Q1  Q2  MissingValueCount
# 0   1   1  -1                  0
# 1   2   3  -1                  0
# 2   3  10   3                  0
# 3   4   9  -1                  0
# 4   5  10   2                  0
# 5   6   1  -1                  0
# 6   7   1  -1                  0
# 7   8   1  -1                  0
# 8   9   9  -1                  0
# 9  10   2  -1                  0
# Number of observations: 10
# Number of entries: 40
#
#
# Displaying mode:
#    Id   Q1   Q2
# 0   1  1.0 -1.0
#  Displaying rest of the quantitative desciptions:
#                        Id         Q1        Q2
# unique_entries   10.00000   5.000000  3.000000
# missing_entries   0.00000   0.000000  0.000000
# extr_val_lower   -5.75000 -15.000000 -1.000000
# extr_val_upper   21.25000  33.000000 -1.000000
# outliers          0.00000   0.000000  2.000000
# mean              5.50000   4.700000 -0.300000
# std_dev           3.02765   4.191261  1.494434
# max              10.00000  10.000000  3.000000
# min               1.00000   1.000000 -1.000000
# Q3                7.75000   9.000000 -1.000000
# Q2 (med)          5.50000   2.500000 -1.000000
# Q1                3.25000   1.000000 -1.000000
# skew              0.00000   0.433042  1.887601
# kurtosis         -1.20000  -2.165842  2.158610

# %%
vizDDA(data3)
